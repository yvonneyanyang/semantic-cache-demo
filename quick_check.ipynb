# %%
# quick_check.py
# Purpose: Test whether Gemini Embedding API works correctly.

# 1. Import required libraries
import os
from dotenv import load_dotenv
import google.generativeai as genai

# 2. Load environment variables from .env file
#    This file should contain your API key as GEMINI_API_KEY
load_dotenv()

# 3. Configure the Gemini client using API key
genai.configure(api_key=os.getenv("AIzaSyAej7JIVuByQTpsvsoErU_OLYxJvyWU3ho"))

# 4. Define the model name for embeddings (text-embedding-004 is the newest and best one)
EMBED_MODEL = "text-embedding-004"

# 5. Create a short test text
test_text = "Climate change affects corn yields across regions."

# 6. Generate an embedding for this text
result = genai.embed_content(model=EMBED_MODEL, content=test_text)

# 7. Print out the embedding length and first few values for verification
embedding = result["embedding"]
print(f"Embedding length: {len(embedding)}")
print("First 5 values:", embedding[:5])
# Out:
# Embedding length: 768
# First 5 values: [0.023825243, 0.017509649, -0.0061570783, 0.03190498, 0.028338948]
